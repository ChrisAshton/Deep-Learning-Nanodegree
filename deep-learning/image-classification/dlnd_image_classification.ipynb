# %% [markdown]
# # Image Classification
# In this project, you'll classify images from the [CIFAR-10 dataset](https://www.cs.toronto.edu/~kriz/cifar.html).  The dataset consists of airplanes, dogs, cats, and other objects. You'll preprocess the images, then train a convolutional neural network on all the samples. The images need to be normalized and the labels need to be one-hot encoded.  You'll get to apply what you learned and build a convolutional, max pooling, dropout, and fully connected layers.  At the end, you'll get to see your neural network's predictions on the sample images.
# ## Get the Data
# Run the following cell to download the [CIFAR-10 dataset for python](https://www.cs.toronto.edu/~kriz/cifar-10-python.tar.gz).

# %%
"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
from urllib.request import urlretrieve
from os.path import isfile, isdir
from tqdm import tqdm
import problem_unittests as tests
import tarfile

cifar10_dataset_folder_path = 'cifar-10-batches-py'

# Use Floyd's cifar-10 dataset if present
floyd_cifar10_location = '/input/cifar-10/python.tar.gz'
if isfile(floyd_cifar10_location):
    tar_gz_path = floyd_cifar10_location
else:
    tar_gz_path = 'cifar-10-python.tar.gz'

class DLProgress(tqdm):
    last_block = 0

    def hook(self, block_num=1, block_size=1, total_size=None):
        self.total = total_size
        self.update((block_num - self.last_block) * block_size)
        self.last_block = block_num

if not isfile(tar_gz_path):
    with DLProgress(unit='B', unit_scale=True, miniters=1, desc='CIFAR-10 Dataset') as pbar:
        urlretrieve(
            'https://www.cs.toronto.edu/~kriz/cifar-10-python.tar.gz',
            tar_gz_path,
            pbar.hook)

if not isdir(cifar10_dataset_folder_path):
    with tarfile.open(tar_gz_path) as tar:
        tar.extractall()
        tar.close()


tests.test_folder_path(cifar10_dataset_folder_path)
# Out:
# All files found!

# %% [markdown]
# ## Explore the Data
# The dataset is broken into batches to prevent your machine from running out of memory.  The CIFAR-10 dataset consists of 5 batches, named `data_batch_1`, `data_batch_2`, etc.. Each batch contains the labels and images that are one of the following:
# * airplane
# * automobile
# * bird
# * cat
# * deer
# * dog
# * frog
# * horse
# * ship
# * truck
#
# Understanding a dataset is part of making predictions on the data.  Play around with the code cell below by changing the `batch_id` and `sample_id`. The `batch_id` is the id for a batch (1-5). The `sample_id` is the id for a image and label pair in the batch.
#
# Ask yourself "What are all possible labels?", "What is the range of values for the image data?", "Are the labels in order or random?".  Answers to questions like these will help you preprocess the data and end up with better predictions.

# %%
# %matplotlib inline
# %config InlineBackend.figure_format = 'retina'

import helper
import numpy as np

# Explore the dataset
batch_id = 1
sample_id = 5
helper.display_stats(cifar10_dataset_folder_path, batch_id, sample_id)
# Out:
# Stats of batch 1:
# Samples: 10000
# Label Counts: {0: 1005, 1: 974, 2: 1032, 3: 1016, 4: 999, 5: 937, 6: 1030, 7: 1001, 8: 1025, 9: 981}
# First 20 Labels: [6, 9, 9, 4, 1, 1, 2, 7, 8, 3, 4, 7, 7, 2, 9, 9, 9, 3, 2, 6]
#
# Example of Image 5:
# Image - Min Value: 0 Max Value: 252
# Image - Shape: (32, 32, 3)
# Label - Label Id: 1 Name: automobile

# %% [markdown]
# ## Implement Preprocess Functions
# ### Normalize
# In the cell below, implement the `normalize` function to take in image data, `x`, and return it as a normalized Numpy array. The values should be in the range of 0 to 1, inclusive.  The return object should be the same shape as `x`.

# %%
def normalize(x):
    """
    Normalize a list of sample image data in the range of 0 to 1
    : x: List of image data.  The image shape is (32, 32, 3)
    : return: Numpy array of normalize data
    """
    a = 0.1
    b = 0.9
    Xmin = 0
    Xmax = 255
    X = x
    
    return a + (((X - Xmin) * (b - a))/(Xmax - Xmin))


"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
tests.test_normalize(normalize)
# Out:
# Tests Passed

# %% [markdown]
# ### One-hot encode
# Just like the previous code cell, you'll be implementing a function for preprocessing.  This time, you'll implement the `one_hot_encode` function. The input, `x`, are a list of labels.  Implement the function to return the list of labels as One-Hot encoded Numpy array.  The possible values for labels are 0 to 9. The one-hot encoding function should return the same encoding for each value between each call to `one_hot_encode`.  Make sure to save the map of encodings outside the function.
#
# Hint: Don't reinvent the wheel.

# %%
# from sklearn.preprocessing import LabelBinarizer
from sklearn.preprocessing import LabelBinarizer

def one_hot_encode(x):
    """
    One hot encode a list of sample labels. Return a one-hot encoded vector for each label.
    : x: List of sample Labels
    : return: Numpy array of one-hot encoded labels
    https://discussions.udacity.com/t/about-one-hot-encoding-error/243124/2
    Has to be shape(len(x), 10) no matter what
    """
#     labels = np.zeros([len(x), 10])
    
#     for i in range(len(x)):
#         labels[i, x[i]] = 1
#     print(x)    
#     print(labels)

#     return labels

    label_binarizer = LabelBinarizer()
    label_binarizer.fit(range(10))
    return label_binarizer.transform(x)


"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
tests.test_one_hot_encode(one_hot_encode)
# Out:
# Tests Passed

# %% [markdown]
# ### Randomize Data
# As you saw from exploring the data above, the order of the samples are randomized.  It doesn't hurt to randomize it again, but you don't need to for this dataset.

# %% [markdown]
# ## Preprocess all the data and save it
# Running the code cell below will preprocess all the CIFAR-10 data and save it to file. The code below also uses 10% of the training data for validation.

# %%
"""
DON'T MODIFY ANYTHING IN THIS CELL
"""
# Preprocess Training, Validation, and Testing Data
helper.preprocess_and_save_data(cifar10_dataset_folder_path, normalize, one_hot_encode)

# %% [markdown]
# # Check Point
# This is your first checkpoint.  If you ever decide to come back to this notebook or have to restart the notebook, you can start from here.  The preprocessed data has been saved to disk.

# %%
"""
DON'T MODIFY ANYTHING IN THIS CELL
"""
import pickle
import problem_unittests as tests
import helper

# Load the Preprocessed Validation data
valid_features, valid_labels = pickle.load(open('preprocess_validation.p', mode='rb'))

# %% [markdown]
# ## Build the network
# For the neural network, you'll build each layer into a function.  Most of the code you've seen has been outside of functions. To test your code more thoroughly, we require that you put each layer in a function.  This allows us to give you better feedback and test for simple mistakes using our unittests before you submit your project.
#
# >**Note:** If you're finding it hard to dedicate enough time for this course each week, we've provided a small shortcut to this part of the project. In the next couple of problems, you'll have the option to use classes from the [TensorFlow Layers](https://www.tensorflow.org/api_docs/python/tf/layers) or [TensorFlow Layers (contrib)](https://www.tensorflow.org/api_guides/python/contrib.layers) packages to build each layer, except the layers you build in the "Convolutional and Max Pooling Layer" section.  TF Layers is similar to Keras's and TFLearn's abstraction to layers, so it's easy to pickup.
#
# >However, if you would like to get the most out of this course, try to solve all the problems _without_ using anything from the TF Layers packages. You **can** still use classes from other packages that happen to have the same name as ones you find in TF Layers! For example, instead of using the TF Layers version of the `conv2d` class, [tf.layers.conv2d](https://www.tensorflow.org/api_docs/python/tf/layers/conv2d), you would want to use the TF Neural Network version of `conv2d`, [tf.nn.conv2d](https://www.tensorflow.org/api_docs/python/tf/nn/conv2d).
#
# Let's begin!
#
# ### Input
# The neural network needs to read the image data, one-hot encoded labels, and dropout keep probability. Implement the following functions
# * Implement `neural_net_image_input`
#  * Return a [TF Placeholder](https://www.tensorflow.org/api_docs/python/tf/placeholder)
#  * Set the shape using `image_shape` with batch size set to `None`.
#  * Name the TensorFlow placeholder "x" using the TensorFlow `name` parameter in the [TF Placeholder](https://www.tensorflow.org/api_docs/python/tf/placeholder).
# * Implement `neural_net_label_input`
#  * Return a [TF Placeholder](https://www.tensorflow.org/api_docs/python/tf/placeholder)
#  * Set the shape using `n_classes` with batch size set to `None`.
#  * Name the TensorFlow placeholder "y" using the TensorFlow `name` parameter in the [TF Placeholder](https://www.tensorflow.org/api_docs/python/tf/placeholder).
# * Implement `neural_net_keep_prob_input`
#  * Return a [TF Placeholder](https://www.tensorflow.org/api_docs/python/tf/placeholder) for dropout keep probability.
#  * Name the TensorFlow placeholder "keep_prob" using the TensorFlow `name` parameter in the [TF Placeholder](https://www.tensorflow.org/api_docs/python/tf/placeholder).
#
# These names will be used at the end of the project to load your saved model.
#
# Note: `None` for shapes in TensorFlow allow for a dynamic size.

# %%
import tensorflow as tf

def neural_net_image_input(image_shape):
    """
    Return a Tensor for a batch of image input
    : image_shape: Shape of the images
    : return: Tensor for image input.
    """
    # TODO: Implement Function
    
    x = tf.placeholder(dtype=tf.float32, shape=[None, image_shape[0], image_shape[1], image_shape[2]], name="x")
    return x


def neural_net_label_input(n_classes):
    """
    Return a Tensor for a batch of label input
    : n_classes: Number of classes
    : return: Tensor for label input.
    """
    # TODO: Implement Function
    
    y = tf.placeholder(dtype=tf.float32, shape=[None, n_classes], name="y")
    return y


def neural_net_keep_prob_input():
    """
    Return a Tensor for keep probability
    : return: Tensor for keep probability.
    """
    # TODO: Implement Function
    keep_prob = tf.placeholder(tf.float32, shape=None, name="keep_prob")
    return keep_prob


"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
tf.reset_default_graph()
tests.test_nn_image_inputs(neural_net_image_input)
tests.test_nn_label_inputs(neural_net_label_input)
tests.test_nn_keep_prob_inputs(neural_net_keep_prob_input)
# Out:
# Image Input Tests Passed.
# Label Input Tests Passed.
# Keep Prob Tests Passed.

# %% [markdown]
# ### Convolution and Max Pooling Layer
# Convolution layers have a lot of success with images. For this code cell, you should implement the function `conv2d_maxpool` to apply convolution then max pooling:
# * Create the weight and bias using `conv_ksize`, `conv_num_outputs` and the shape of `x_tensor`.
# * Apply a convolution to `x_tensor` using weight and `conv_strides`.
#  * We recommend you use same padding, but you're welcome to use any padding.
# * Add bias
# * Add a nonlinear activation to the convolution.
# * Apply Max Pooling using `pool_ksize` and `pool_strides`.
#  * We recommend you use same padding, but you're welcome to use any padding.
#
# **Note:** You **can't** use [TensorFlow Layers](https://www.tensorflow.org/api_docs/python/tf/layers) or [TensorFlow Layers (contrib)](https://www.tensorflow.org/api_guides/python/contrib.layers) for **this** layer, but you can still use TensorFlow's [Neural Network](https://www.tensorflow.org/api_docs/python/tf/nn) package. You may still use the shortcut option for all the **other** layers.

# %%
def conv2d_maxpool(x_tensor, conv_num_outputs, conv_ksize, conv_strides, pool_ksize, pool_strides):
    """
    Apply convolution then max pooling to x_tensor
    :param x_tensor: TensorFlow Tensor
    :param conv_num_outputs: Number of outputs for the convolutional layer
    :param conv_ksize: kernal size 2-D Tuple for the convolutional layer
    :param conv_strides: Stride 2-D Tuple for convolution
    :param pool_ksize: kernal size 2-D Tuple for pool
    :param pool_strides: Stride 2-D Tuple for pool
    : return: A tensor that represents convolution and max pooling of x_tensor
    """
    # TODO: Implement Function
    
#     print(type(x_tensor.shape[-1]))
#     print(type(x_tensor.get_shape().as_list()[-1]))
    
    weights = tf.Variable(tf.truncated_normal(shape=[conv_ksize[0],
                                                     conv_ksize[1], 
                                                     x_tensor.get_shape().as_list()[-1], 
                                                     conv_num_outputs], 
                                              mean=0.0, 
                                              stddev=1.0, 
                                              dtype=tf.float32, 
                                              seed=None
                                             )
                         )
    bias = tf.Variable(tf.zeros(conv_num_outputs))
    
    x_tensor = tf.nn.conv2d(x_tensor, 
                            weights, 
                            strides=[1, 
                                     conv_strides[0], 
                                     conv_strides[1], 
                                     1], 
                            padding='SAME' 
                           )
    x_tensor = tf.nn.bias_add(x_tensor, bias)
    x_tensor = tf.nn.relu(x_tensor)
    
    return tf.nn.max_pool(x_tensor, 
                          ksize=[1, 
                                 pool_ksize[0], 
                                 pool_ksize[1], 
                                 1], 
                          strides=[1, 
                                   pool_strides[0], 
                                   pool_strides[1], 
                                   1], 
                          padding='SAME'
                         )


"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
tests.test_con_pool(conv2d_maxpool)
# Out:
# Tests Passed

# %% [markdown]
# ### Flatten Layer
# Implement the `flatten` function to change the dimension of `x_tensor` from a 4-D tensor to a 2-D tensor.  The output should be the shape (*Batch Size*, *Flattened Image Size*). Shortcut option: you can use classes from the [TensorFlow Layers](https://www.tensorflow.org/api_docs/python/tf/layers) or [TensorFlow Layers (contrib)](https://www.tensorflow.org/api_guides/python/contrib.layers) packages for this layer. For more of a challenge, only use other TensorFlow packages.

# %%
def flatten(x_tensor):
    """
    Flatten x_tensor to (Batch Size, Flattened Image Size)
    : x_tensor: A tensor of size (Batch Size, ...), where ... are the image dimensions.
    : return: A tensor of size (Batch Size, Flattened Image Size).
    """
    # TODO: Implement Function
    return tf.contrib.layers.flatten(x_tensor)


"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
tests.test_flatten(flatten)
# Out:
# Tests Passed

# %% [markdown]
# ### Fully-Connected Layer
# Implement the `fully_conn` function to apply a fully connected layer to `x_tensor` with the shape (*Batch Size*, *num_outputs*). Shortcut option: you can use classes from the [TensorFlow Layers](https://www.tensorflow.org/api_docs/python/tf/layers) or [TensorFlow Layers (contrib)](https://www.tensorflow.org/api_guides/python/contrib.layers) packages for this layer. For more of a challenge, only use other TensorFlow packages.

# %%
def fully_conn(x_tensor, num_outputs):
    """
    Apply a fully connected layer to x_tensor **using weight and bias
    : x_tensor: A 2-D tensor where the first dimension is batch size.
    : num_outputs: The number of output that the new tensor should be.
    : return: A 2-D tensor where the second dimension is num_outputs.
    """
    # TODO: Implement Function
    weights = tf.Variable(tf.truncated_normal(shape=[x_tensor.get_shape().as_list()[-1], 
                                                     num_outputs], 
                                              mean=0.0, 
                                              stddev=.01, 
                                              dtype=tf.float32, 
                                              seed=None
                                             )
                         )
    bias = tf.Variable(tf.zeros(num_outputs))
    

    return tf.nn.softsign(tf.add(tf.matmul(x_tensor,weights), bias))


"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
tests.test_fully_conn(fully_conn)
# Out:
# Tests Passed

# %% [markdown]
# ### Output Layer
# Implement the `output` function to apply a fully connected layer to `x_tensor` with the shape (*Batch Size*, *num_outputs*). Shortcut option: you can use classes from the [TensorFlow Layers](https://www.tensorflow.org/api_docs/python/tf/layers) or [TensorFlow Layers (contrib)](https://www.tensorflow.org/api_guides/python/contrib.layers) packages for this layer. For more of a challenge, only use other TensorFlow packages.
#
# **Note:** Activation, softmax, or cross entropy should **not** be applied to this.

# %%
def output(x_tensor, num_outputs):
    """
    Apply a output layer to x_tensor **using weight and bias
    : x_tensor: A 2-D tensor where the first dimension is batch size.
    : num_outputs: The number of output that the new tensor should be.
    : return: A 2-D tensor where the second dimension is num_outputs.
    """
    # TODO: Implement Function
    weights = tf.Variable(tf.truncated_normal(shape=[x_tensor.get_shape().as_list()[-1], 
                                                     num_outputs], 
                                              mean=0.0, 
                                              stddev=.01, 
                                              dtype=tf.float32, 
                                              seed=None
                                             )
                         )
    bias = tf.Variable(tf.zeros(num_outputs))
    

    return tf.add(tf.matmul(x_tensor,weights), bias)


"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
tests.test_output(output)
# Out:
# Tests Passed

# %% [markdown]
# ### Create Convolutional Model
# Implement the function `conv_net` to create a convolutional neural network model. The function takes in a batch of images, `x`, and outputs logits.  Use the layers you created above to create this model:
#
# * Apply 1, 2, or 3 Convolution and Max Pool layers
# * Apply a Flatten Layer
# * Apply 1, 2, or 3 Fully Connected Layers
# * Apply an Output Layer
# * Return the output
# * Apply [TensorFlow's Dropout](https://www.tensorflow.org/api_docs/python/tf/nn/dropout) to one or more layers in the model using `keep_prob`.

# %%
def conv_net(x, keep_prob):
    """
    Create a convolutional neural network model
    : x: Placeholder tensor that holds image data.
    : keep_prob: Placeholder tensor that hold dropout keep probability.
    : return: Tensor that represents logits
    """
    # TODO: Apply 1, 2, or 3 Convolution and Max Pool layers
    #    Play around with different number of outputs, kernel size and stride
    # Function Definition from Above:
    conv_num_outputs = 64
    num_outputs = 10
    conv_ksize = (4,4)
    conv_strides = (1,1)
    pool_ksize = (8,8)#(4,4)
    pool_strides = (1,1)
    
    conv_layer1 = conv2d_maxpool(x, conv_num_outputs, conv_ksize, conv_strides, pool_ksize, pool_strides)
    dropout_layer = tf.nn.dropout(conv_layer1, keep_prob)
    #conv_layer2 = conv2d_maxpool(dropout_layer, conv_num_outputs, conv_ksize, conv_strides, pool_ksize, pool_strides)
    

    # TODO: Apply a Flatten Layer
    # Function Definition from Above:
    flattened_layer = flatten(dropout_layer)
    

    # TODO: Apply 1, 2, or 3 Fully Connected Layers
    #    Play around with different number of outputs
    # Function Definition from Above:
    full_net_result = fully_conn(flattened_layer,400)#50)
    
    
    # TODO: Apply an Output Layer
    #    Set this to the number of classes
    # Function Definition from Above:
    net_output = output(full_net_result, num_outputs)
    
    
    # TODO: return output
    return net_output


"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""

##############################
## Build the Neural Network ##
##############################

# Remove previous weights, bias, inputs, etc..
tf.reset_default_graph()

# Inputs
x = neural_net_image_input((32, 32, 3))
y = neural_net_label_input(10)
keep_prob = neural_net_keep_prob_input()

# Model
logits = conv_net(x, keep_prob)

# Name logits Tensor, so that is can be loaded from disk after training
logits = tf.identity(logits, name='logits')

# Loss and Optimizer
cost = tf.reduce_mean(tf.nn.softmax_cross_entropy_with_logits(logits=logits, labels=y))
optimizer = tf.train.AdamOptimizer().minimize(cost)

# Accuracy
correct_pred = tf.equal(tf.argmax(logits, 1), tf.argmax(y, 1))
accuracy = tf.reduce_mean(tf.cast(correct_pred, tf.float32), name='accuracy')

tests.test_conv_net(conv_net)
# Out:
# Neural Network Built!

# %% [markdown]
# ## Train the Neural Network
# ### Single Optimization
# Implement the function `train_neural_network` to do a single optimization.  The optimization should use `optimizer` to optimize in `session` with a `feed_dict` of the following:
# * `x` for image input
# * `y` for labels
# * `keep_prob` for keep probability for dropout
#
# This function will be called for each batch, so `tf.global_variables_initializer()` has already been called.
#
# Note: Nothing needs to be returned. This function is only optimizing the neural network.

# %%
def train_neural_network(session, optimizer, keep_probability, feature_batch, label_batch):
    """
    Optimize the session on a batch of images and labels
    : session: Current TensorFlow session
    : optimizer: TensorFlow optimizer function
    : keep_probability: keep probability
    : feature_batch: Batch of Numpy image data
    : label_batch: Batch of Numpy label data
    """
    # TODO: Implement Function
    session.run(optimizer, feed_dict={x: feature_batch, y: label_batch, keep_prob: keep_probability})


"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
tests.test_train_nn(train_neural_network)
# Out:
# Tests Passed

# %% [markdown]
# ### Show Stats
# Implement the function `print_stats` to print loss and validation accuracy.  Use the global variables `valid_features` and `valid_labels` to calculate validation accuracy.  Use a keep probability of `1.0` to calculate the loss and validation accuracy.

# %%
def print_stats(session, feature_batch, label_batch, cost, accuracy):
    """
    Print information about loss and validation accuracy
    : session: Current TensorFlow session
    : feature_batch: Batch of Numpy image data
    : label_batch: Batch of Numpy label data
    : cost: TensorFlow cost function
    : accuracy: TensorFlow accuracy function
    """
    # TODO: Implement Function
    loss = session.run(cost, feed_dict={x: feature_batch, y: label_batch, keep_prob: 1.})
    test_accuracy = session.run(accuracy, feed_dict={x: valid_features, y: valid_labels, keep_prob: 1.})
    print('Loss: {:>10.4f} Validation Accuracy: {:.6f}'.format(
                loss,
                test_accuracy))

# %% [markdown]
# ### Hyperparameters
# Tune the following parameters:
# * Set `epochs` to the number of iterations until the network stops learning or start overfitting
# * Set `batch_size` to the highest number that your machine has memory for.  Most people set them to common sizes of memory:
#  * 64
#  * 128
#  * 256
#  * ...
# * Set `keep_probability` to the probability of keeping a node using dropout

# %%
# TODO: Tune Parameters
epochs = 100
batch_size = 1024
keep_probability = .3

# %% [markdown]
# ### Train on a Single CIFAR-10 Batch
# Instead of training the neural network on all the CIFAR-10 batches of data, let's use a single batch. This should save time while you iterate on the model to get a better accuracy.  Once the final validation accuracy is 50% or greater, run the model on all the data in the next section.

# %%
"""
DON'T MODIFY ANYTHING IN THIS CELL
"""
print('Checking the Training on a Single Batch...')
with tf.Session() as sess:
    # Initializing the variables
    sess.run(tf.global_variables_initializer())
    
    # Training cycle
    for epoch in range(epochs):
        batch_i = 1
        for batch_features, batch_labels in helper.load_preprocess_training_batch(batch_i, batch_size):
            train_neural_network(sess, optimizer, keep_probability, batch_features, batch_labels)
        print('Epoch {:>2}, CIFAR-10 Batch {}:  '.format(epoch + 1, batch_i), end='')
        print_stats(sess, batch_features, batch_labels, cost, accuracy)
# Out:
# Checking the Training on a Single Batch...
# Epoch  1, CIFAR-10 Batch 1:  Loss:     2.2527 Validation Accuracy: 0.146800
# Epoch  2, CIFAR-10 Batch 1:  Loss:     2.1751 Validation Accuracy: 0.236000
# Epoch  3, CIFAR-10 Batch 1:  Loss:     2.0912 Validation Accuracy: 0.282600
# Epoch  4, CIFAR-10 Batch 1:  Loss:     2.0022 Validation Accuracy: 0.297200
# Epoch  5, CIFAR-10 Batch 1:  Loss:     1.9341 Validation Accuracy: 0.321800
# Epoch  6, CIFAR-10 Batch 1:  Loss:     1.8951 Validation Accuracy: 0.320600
# Epoch  7, CIFAR-10 Batch 1:  Loss:     1.8509 Validation Accuracy: 0.331600
# Epoch  8, CIFAR-10 Batch 1:  Loss:     1.8018 Validation Accuracy: 0.355600
# Epoch  9, CIFAR-10 Batch 1:  Loss:     1.7546 Validation Accuracy: 0.360600
# Epoch 10, CIFAR-10 Batch 1:  Loss:     1.7324 Validation Accuracy: 0.367800
# Epoch 11, CIFAR-10 Batch 1:  Loss:     1.6898 Validation Accuracy: 0.392400
# Epoch 12, CIFAR-10 Batch 1:  Loss:     1.6781 Validation Accuracy: 0.401800
# Epoch 13, CIFAR-10 Batch 1:  Loss:     1.6547 Validation Accuracy: 0.396600
# Epoch 14, CIFAR-10 Batch 1:  Loss:     1.6342 Validation Accuracy: 0.402600
# Epoch 15, CIFAR-10 Batch 1:  Loss:     1.6040 Validation Accuracy: 0.412400
# Epoch 16, CIFAR-10 Batch 1:  Loss:     1.5836 Validation Accuracy: 0.422800
# Epoch 17, CIFAR-10 Batch 1:  Loss:     1.5653 Validation Accuracy: 0.439200
# Epoch 18, CIFAR-10 Batch 1:  Loss:     1.5369 Validation Accuracy: 0.447000
# Epoch 19, CIFAR-10 Batch 1:  Loss:     1.5446 Validation Accuracy: 0.448400
# Epoch 20, CIFAR-10 Batch 1:  Loss:     1.5535 Validation Accuracy: 0.452600
# Epoch 21, CIFAR-10 Batch 1:  Loss:     1.5048 Validation Accuracy: 0.438400
# Epoch 22, CIFAR-10 Batch 1:  Loss:     1.4988 Validation Accuracy: 0.448400
# Epoch 23, CIFAR-10 Batch 1:  Loss:     1.4642 Validation Accuracy: 0.467200
# Epoch 24, CIFAR-10 Batch 1:  Loss:     1.4498 Validation Accuracy: 0.468400
# Epoch 25, CIFAR-10 Batch 1:  Loss:     1.4393 Validation Accuracy: 0.457000
# Epoch 26, CIFAR-10 Batch 1:  Loss:     1.4338 Validation Accuracy: 0.470600
# Epoch 27, CIFAR-10 Batch 1:  Loss:     1.4278 Validation Accuracy: 0.461600
# Epoch 28, CIFAR-10 Batch 1:  Loss:     1.4071 Validation Accuracy: 0.480800
# Epoch 29, CIFAR-10 Batch 1:  Loss:     1.4101 Validation Accuracy: 0.478200
# Epoch 30, CIFAR-10 Batch 1:  Loss:     1.4062 Validation Accuracy: 0.473800
# Epoch 31, CIFAR-10 Batch 1:  Loss:     1.3680 Validation Accuracy: 0.484000
# Epoch 32, CIFAR-10 Batch 1:  Loss:     1.3552 Validation Accuracy: 0.485600
# Epoch 33, CIFAR-10 Batch 1:  Loss:     1.3402 Validation Accuracy: 0.483200
# Epoch 34, CIFAR-10 Batch 1:  Loss:     1.3623 Validation Accuracy: 0.484800
# Epoch 35, CIFAR-10 Batch 1:  Loss:     1.3112 Validation Accuracy: 0.494000
# Epoch 36, CIFAR-10 Batch 1:  Loss:     1.2952 Validation Accuracy: 0.494000
# Epoch 37, CIFAR-10 Batch 1:  Loss:     1.3081 Validation Accuracy: 0.498600
# Epoch 38, CIFAR-10 Batch 1:  Loss:     1.2776 Validation Accuracy: 0.507400
# Epoch 39, CIFAR-10 Batch 1:  Loss:     1.2803 Validation Accuracy: 0.514800
# Epoch 40, CIFAR-10 Batch 1:  Loss:     1.2782 Validation Accuracy: 0.510800
# Epoch 41, CIFAR-10 Batch 1:  Loss:     1.2315 Validation Accuracy: 0.517600
# Epoch 42, CIFAR-10 Batch 1:  Loss:     1.2295 Validation Accuracy: 0.519400
# Epoch 43, CIFAR-10 Batch 1:  Loss:     1.2292 Validation Accuracy: 0.524400
# Epoch 44, CIFAR-10 Batch 1:  Loss:     1.2080 Validation Accuracy: 0.529800
# Epoch 45, CIFAR-10 Batch 1:  Loss:     1.2084 Validation Accuracy: 0.533000
# Epoch 46, CIFAR-10 Batch 1:  Loss:     1.2083 Validation Accuracy: 0.521400
# Epoch 47, CIFAR-10 Batch 1:  Loss:     1.1749 Validation Accuracy: 0.527400
# Epoch 48, CIFAR-10 Batch 1:  Loss:     1.1834 Validation Accuracy: 0.518800
# Epoch 49, CIFAR-10 Batch 1:  Loss:     1.2021 Validation Accuracy: 0.521000
# Epoch 50, CIFAR-10 Batch 1:  Loss:     1.1861 Validation Accuracy: 0.525800
# Epoch 51, CIFAR-10 Batch 1:  Loss:     1.1747 Validation Accuracy: 0.530400
# Epoch 52, CIFAR-10 Batch 1:  Loss:     1.1547 Validation Accuracy: 0.533800
# Epoch 53, CIFAR-10 Batch 1:  Loss:     1.1396 Validation Accuracy: 0.535600
# Epoch 54, CIFAR-10 Batch 1:  Loss:     1.1667 Validation Accuracy: 0.532400
# Epoch 55, CIFAR-10 Batch 1:  Loss:     1.2063 Validation Accuracy: 0.512400
# Epoch 56, CIFAR-10 Batch 1:  Loss:     1.1561 Validation Accuracy: 0.527800
# Epoch 57, CIFAR-10 Batch 1:  Loss:     1.1586 Validation Accuracy: 0.529200
# Epoch 58, CIFAR-10 Batch 1:  Loss:     1.1142 Validation Accuracy: 0.528600
# Epoch 59, CIFAR-10 Batch 1:  Loss:     1.0818 Validation Accuracy: 0.541000
# Epoch 60, CIFAR-10 Batch 1:  Loss:     1.1077 Validation Accuracy: 0.540000
# Epoch 61, CIFAR-10 Batch 1:  Loss:     1.1008 Validation Accuracy: 0.540400
# Epoch 62, CIFAR-10 Batch 1:  Loss:     1.0524 Validation Accuracy: 0.546600
# Epoch 63, CIFAR-10 Batch 1:  Loss:     1.0521 Validation Accuracy: 0.536600
# Epoch 64, CIFAR-10 Batch 1:  Loss:     1.1148 Validation Accuracy: 0.529800
# Epoch 65, CIFAR-10 Batch 1:  Loss:     1.0538 Validation Accuracy: 0.543000
# Epoch 66, CIFAR-10 Batch 1:  Loss:     1.0387 Validation Accuracy: 0.538800
# Epoch 67, CIFAR-10 Batch 1:  Loss:     1.0403 Validation Accuracy: 0.555600
# Epoch 68, CIFAR-10 Batch 1:  Loss:     1.0115 Validation Accuracy: 0.553000
# Epoch 69, CIFAR-10 Batch 1:  Loss:     1.0504 Validation Accuracy: 0.549400
# Epoch 70, CIFAR-10 Batch 1:  Loss:     1.0416 Validation Accuracy: 0.549400
# Epoch 71, CIFAR-10 Batch 1:  Loss:     1.0473 Validation Accuracy: 0.547400
# Epoch 72, CIFAR-10 Batch 1:  Loss:     1.0427 Validation Accuracy: 0.542600
# Epoch 73, CIFAR-10 Batch 1:  Loss:     1.0306 Validation Accuracy: 0.559200
# Epoch 74, CIFAR-10 Batch 1:  Loss:     0.9988 Validation Accuracy: 0.557400
# Epoch 75, CIFAR-10 Batch 1:  Loss:     1.0232 Validation Accuracy: 0.546800
# Epoch 76, CIFAR-10 Batch 1:  Loss:     0.9860 Validation Accuracy: 0.556200
# Epoch 77, CIFAR-10 Batch 1:  Loss:     1.0014 Validation Accuracy: 0.551400
# Epoch 78, CIFAR-10 Batch 1:  Loss:     0.9865 Validation Accuracy: 0.547000
# Epoch 79, CIFAR-10 Batch 1:  Loss:     0.9996 Validation Accuracy: 0.557600
# Epoch 80, CIFAR-10 Batch 1:  Loss:     0.9765 Validation Accuracy: 0.550800
# Epoch 81, CIFAR-10 Batch 1:  Loss:     0.9751 Validation Accuracy: 0.560400
# Epoch 82, CIFAR-10 Batch 1:  Loss:     0.9853 Validation Accuracy: 0.562200
# Epoch 83, CIFAR-10 Batch 1:  Loss:     0.9656 Validation Accuracy: 0.553400
# Epoch 84, CIFAR-10 Batch 1:  Loss:     0.9508 Validation Accuracy: 0.555200
# Epoch 85, CIFAR-10 Batch 1:  Loss:     0.9338 Validation Accuracy: 0.556200
# Epoch 86, CIFAR-10 Batch 1:  Loss:     0.9793 Validation Accuracy: 0.557600
# Epoch 87, CIFAR-10 Batch 1:  Loss:     0.9380 Validation Accuracy: 0.559000
# Epoch 88, CIFAR-10 Batch 1:  Loss:     0.9083 Validation Accuracy: 0.558800
# Epoch 89, CIFAR-10 Batch 1:  Loss:     0.8717 Validation Accuracy: 0.564000
# Epoch 90, CIFAR-10 Batch 1:  Loss:     0.8974 Validation Accuracy: 0.560800
# Epoch 91, CIFAR-10 Batch 1:  Loss:     0.9039 Validation Accuracy: 0.572600
# Epoch 92, CIFAR-10 Batch 1:  Loss:     0.9056 Validation Accuracy: 0.569200
# Epoch 93, CIFAR-10 Batch 1:  Loss:     0.9649 Validation Accuracy: 0.556800
# Epoch 94, CIFAR-10 Batch 1:  Loss:     0.9265 Validation Accuracy: 0.562800
# Epoch 95, CIFAR-10 Batch 1:  Loss:     0.9523 Validation Accuracy: 0.555000
# Epoch 96, CIFAR-10 Batch 1:  Loss:     0.8972 Validation Accuracy: 0.564200
# Epoch 97, CIFAR-10 Batch 1:  Loss:     0.8901 Validation Accuracy: 0.562600
# Epoch 98, CIFAR-10 Batch 1:  Loss:     0.9095 Validation Accuracy: 0.562600
# Epoch 99, CIFAR-10 Batch 1:  Loss:     0.8688 Validation Accuracy: 0.573600
# Epoch 100, CIFAR-10 Batch 1:  Loss:     0.8401 Validation Accuracy: 0.572600

# %% [markdown]
# ### Fully Train the Model
# Now that you got a good accuracy with a single CIFAR-10 batch, try it with all five batches.

# %%
"""
DON'T MODIFY ANYTHING IN THIS CELL
"""
save_model_path = './image_classification'

print('Training...')
with tf.Session() as sess:
    # Initializing the variables
    sess.run(tf.global_variables_initializer())
    
    # Training cycle
    for epoch in range(epochs):
        # Loop over all batches
        n_batches = 5
        for batch_i in range(1, n_batches + 1):
            for batch_features, batch_labels in helper.load_preprocess_training_batch(batch_i, batch_size):
                train_neural_network(sess, optimizer, keep_probability, batch_features, batch_labels)
            print('Epoch {:>2}, CIFAR-10 Batch {}:  '.format(epoch + 1, batch_i), end='')
            print_stats(sess, batch_features, batch_labels, cost, accuracy)
            
    # Save Model
    saver = tf.train.Saver()
    save_path = saver.save(sess, save_model_path)
# Out:
# Training...
# Epoch  1, CIFAR-10 Batch 1:  Loss:     2.2669 Validation Accuracy: 0.149400
# Epoch  1, CIFAR-10 Batch 2:  Loss:     2.2111 Validation Accuracy: 0.197400
# Epoch  1, CIFAR-10 Batch 3:  Loss:     2.1267 Validation Accuracy: 0.255400
# Epoch  1, CIFAR-10 Batch 4:  Loss:     2.0710 Validation Accuracy: 0.236800
# Epoch  1, CIFAR-10 Batch 5:  Loss:     1.9978 Validation Accuracy: 0.276400
# Epoch  2, CIFAR-10 Batch 1:  Loss:     1.9857 Validation Accuracy: 0.317400
# Epoch  2, CIFAR-10 Batch 2:  Loss:     1.8974 Validation Accuracy: 0.283600
# Epoch  2, CIFAR-10 Batch 3:  Loss:     1.8477 Validation Accuracy: 0.328400
# Epoch  2, CIFAR-10 Batch 4:  Loss:     1.8220 Validation Accuracy: 0.316800
# Epoch  2, CIFAR-10 Batch 5:  Loss:     1.8066 Validation Accuracy: 0.338600
# Epoch  3, CIFAR-10 Batch 1:  Loss:     1.7809 Validation Accuracy: 0.372800
# Epoch  3, CIFAR-10 Batch 2:  Loss:     1.7432 Validation Accuracy: 0.355000
# Epoch  3, CIFAR-10 Batch 3:  Loss:     1.6893 Validation Accuracy: 0.386600
# Epoch  3, CIFAR-10 Batch 4:  Loss:     1.6642 Validation Accuracy: 0.384000
# Epoch  3, CIFAR-10 Batch 5:  Loss:     1.6876 Validation Accuracy: 0.380000
# Epoch  4, CIFAR-10 Batch 1:  Loss:     1.6704 Validation Accuracy: 0.385000
# Epoch  4, CIFAR-10 Batch 2:  Loss:     1.6330 Validation Accuracy: 0.409000
# Epoch  4, CIFAR-10 Batch 3:  Loss:     1.5816 Validation Accuracy: 0.429200
# Epoch  4, CIFAR-10 Batch 4:  Loss:     1.5717 Validation Accuracy: 0.425400
# Epoch  4, CIFAR-10 Batch 5:  Loss:     1.5835 Validation Accuracy: 0.412800
# Epoch  5, CIFAR-10 Batch 1:  Loss:     1.5846 Validation Accuracy: 0.421600
# Epoch  5, CIFAR-10 Batch 2:  Loss:     1.5541 Validation Accuracy: 0.435400
# Epoch  5, CIFAR-10 Batch 3:  Loss:     1.5167 Validation Accuracy: 0.439600
# Epoch  5, CIFAR-10 Batch 4:  Loss:     1.4862 Validation Accuracy: 0.442800
# Epoch  5, CIFAR-10 Batch 5:  Loss:     1.5403 Validation Accuracy: 0.452000
# Epoch  6, CIFAR-10 Batch 1:  Loss:     1.4799 Validation Accuracy: 0.459200
# Epoch  6, CIFAR-10 Batch 2:  Loss:     1.4913 Validation Accuracy: 0.459400
# Epoch  6, CIFAR-10 Batch 3:  Loss:     1.4328 Validation Accuracy: 0.468400
# Epoch  6, CIFAR-10 Batch 4:  Loss:     1.4688 Validation Accuracy: 0.460200
# Epoch  6, CIFAR-10 Batch 5:  Loss:     1.4850 Validation Accuracy: 0.465400
# Epoch  7, CIFAR-10 Batch 1:  Loss:     1.4567 Validation Accuracy: 0.474000
# Epoch  7, CIFAR-10 Batch 2:  Loss:     1.4211 Validation Accuracy: 0.479600
# Epoch  7, CIFAR-10 Batch 3:  Loss:     1.3990 Validation Accuracy: 0.477000
# Epoch  7, CIFAR-10 Batch 4:  Loss:     1.3876 Validation Accuracy: 0.477000
# Epoch  7, CIFAR-10 Batch 5:  Loss:     1.4323 Validation Accuracy: 0.471600
# Epoch  8, CIFAR-10 Batch 1:  Loss:     1.3980 Validation Accuracy: 0.481400
# Epoch  8, CIFAR-10 Batch 2:  Loss:     1.3861 Validation Accuracy: 0.491000
# Epoch  8, CIFAR-10 Batch 3:  Loss:     1.3440 Validation Accuracy: 0.485800
# Epoch  8, CIFAR-10 Batch 4:  Loss:     1.3477 Validation Accuracy: 0.488200
# Epoch  8, CIFAR-10 Batch 5:  Loss:     1.3576 Validation Accuracy: 0.499400
# Epoch  9, CIFAR-10 Batch 1:  Loss:     1.3583 Validation Accuracy: 0.505200
# Epoch  9, CIFAR-10 Batch 2:  Loss:     1.3444 Validation Accuracy: 0.502600
# Epoch  9, CIFAR-10 Batch 3:  Loss:     1.3313 Validation Accuracy: 0.493600
# Epoch  9, CIFAR-10 Batch 4:  Loss:     1.2789 Validation Accuracy: 0.508600
# Epoch  9, CIFAR-10 Batch 5:  Loss:     1.3430 Validation Accuracy: 0.495800
# Epoch 10, CIFAR-10 Batch 1:  Loss:     1.3188 Validation Accuracy: 0.509600
# Epoch 10, CIFAR-10 Batch 2:  Loss:     1.3253 Validation Accuracy: 0.517400
# Epoch 10, CIFAR-10 Batch 3:  Loss:     1.2871 Validation Accuracy: 0.521600
# Epoch 10, CIFAR-10 Batch 4:  Loss:     1.2630 Validation Accuracy: 0.512600
# Epoch 10, CIFAR-10 Batch 5:  Loss:     1.3213 Validation Accuracy: 0.519000
# Epoch 11, CIFAR-10 Batch 1:  Loss:     1.3266 Validation Accuracy: 0.519600
# Epoch 11, CIFAR-10 Batch 2:  Loss:     1.2984 Validation Accuracy: 0.525200
# Epoch 11, CIFAR-10 Batch 3:  Loss:     1.2545 Validation Accuracy: 0.530600
# Epoch 11, CIFAR-10 Batch 4:  Loss:     1.2606 Validation Accuracy: 0.528200
# Epoch 11, CIFAR-10 Batch 5:  Loss:     1.2702 Validation Accuracy: 0.532800
# Epoch 12, CIFAR-10 Batch 1:  Loss:     1.2760 Validation Accuracy: 0.536000
# Epoch 12, CIFAR-10 Batch 2:  Loss:     1.2738 Validation Accuracy: 0.523400
# Epoch 12, CIFAR-10 Batch 3:  Loss:     1.2468 Validation Accuracy: 0.525000
# Epoch 12, CIFAR-10 Batch 4:  Loss:     1.2183 Validation Accuracy: 0.530000
# Epoch 12, CIFAR-10 Batch 5:  Loss:     1.2634 Validation Accuracy: 0.531200
# Epoch 13, CIFAR-10 Batch 1:  Loss:     1.2688 Validation Accuracy: 0.536000
# Epoch 13, CIFAR-10 Batch 2:  Loss:     1.2894 Validation Accuracy: 0.523200
# Epoch 13, CIFAR-10 Batch 3:  Loss:     1.2218 Validation Accuracy: 0.530400
# Epoch 13, CIFAR-10 Batch 4:  Loss:     1.1992 Validation Accuracy: 0.541000
# Epoch 13, CIFAR-10 Batch 5:  Loss:     1.2018 Validation Accuracy: 0.551800
# Epoch 14, CIFAR-10 Batch 1:  Loss:     1.1960 Validation Accuracy: 0.551000
# Epoch 14, CIFAR-10 Batch 2:  Loss:     1.2266 Validation Accuracy: 0.551000
# Epoch 14, CIFAR-10 Batch 3:  Loss:     1.1970 Validation Accuracy: 0.547800
# Epoch 14, CIFAR-10 Batch 4:  Loss:     1.1607 Validation Accuracy: 0.544800
# Epoch 14, CIFAR-10 Batch 5:  Loss:     1.2028 Validation Accuracy: 0.542800
# Epoch 15, CIFAR-10 Batch 1:  Loss:     1.2293 Validation Accuracy: 0.537400
# Epoch 15, CIFAR-10 Batch 2:  Loss:     1.2082 Validation Accuracy: 0.545400
# Epoch 15, CIFAR-10 Batch 3:  Loss:     1.1977 Validation Accuracy: 0.541200
# Epoch 15, CIFAR-10 Batch 4:  Loss:     1.2173 Validation Accuracy: 0.535800
# Epoch 15, CIFAR-10 Batch 5:  Loss:     1.1746 Validation Accuracy: 0.547000
# Epoch 16, CIFAR-10 Batch 1:  Loss:     1.2307 Validation Accuracy: 0.540600
# Epoch 16, CIFAR-10 Batch 2:  Loss:     1.2329 Validation Accuracy: 0.544400
# Epoch 16, CIFAR-10 Batch 3:  Loss:     1.2036 Validation Accuracy: 0.546400
# Epoch 16, CIFAR-10 Batch 4:  Loss:     1.1763 Validation Accuracy: 0.540800
# Epoch 16, CIFAR-10 Batch 5:  Loss:     1.1658 Validation Accuracy: 0.540000
# Epoch 17, CIFAR-10 Batch 1:  Loss:     1.1981 Validation Accuracy: 0.560800
# Epoch 17, CIFAR-10 Batch 2:  Loss:     1.1860 Validation Accuracy: 0.563600
# Epoch 17, CIFAR-10 Batch 3:  Loss:     1.1507 Validation Accuracy: 0.560800
# Epoch 17, CIFAR-10 Batch 4:  Loss:     1.1417 Validation Accuracy: 0.549400
# Epoch 17, CIFAR-10 Batch 5:  Loss:     1.1273 Validation Accuracy: 0.561800
# Epoch 18, CIFAR-10 Batch 1:  Loss:     1.1740 Validation Accuracy: 0.560400
# Epoch 18, CIFAR-10 Batch 2:  Loss:     1.1727 Validation Accuracy: 0.552200
# Epoch 18, CIFAR-10 Batch 3:  Loss:     1.1158 Validation Accuracy: 0.558200
# Epoch 18, CIFAR-10 Batch 4:  Loss:     1.1389 Validation Accuracy: 0.558000
# Epoch 18, CIFAR-10 Batch 5:  Loss:     1.1595 Validation Accuracy: 0.562600
# Epoch 19, CIFAR-10 Batch 1:  Loss:     1.1489 Validation Accuracy: 0.569000
# Epoch 19, CIFAR-10 Batch 2:  Loss:     1.1791 Validation Accuracy: 0.573600
# Epoch 19, CIFAR-10 Batch 3:  Loss:     1.1203 Validation Accuracy: 0.560200
# Epoch 19, CIFAR-10 Batch 4:  Loss:     1.1168 Validation Accuracy: 0.559800
# Epoch 19, CIFAR-10 Batch 5:  Loss:     1.1336 Validation Accuracy: 0.568000
# Epoch 20, CIFAR-10 Batch 1:  Loss:     1.1553 Validation Accuracy: 0.572200
# Epoch 20, CIFAR-10 Batch 2:  Loss:     1.0994 Validation Accuracy: 0.578000
# Epoch 20, CIFAR-10 Batch 3:  Loss:     1.1158 Validation Accuracy: 0.582200
# Epoch 20, CIFAR-10 Batch 4:  Loss:     1.1146 Validation Accuracy: 0.562600
# Epoch 20, CIFAR-10 Batch 5:  Loss:     1.0986 Validation Accuracy: 0.573200
# Epoch 21, CIFAR-10 Batch 1:  Loss:     1.1376 Validation Accuracy: 0.571200
# Epoch 21, CIFAR-10 Batch 2:  Loss:     1.1151 Validation Accuracy: 0.577000
# Epoch 21, CIFAR-10 Batch 3:  Loss:     1.1258 Validation Accuracy: 0.574600
# Epoch 21, CIFAR-10 Batch 4:  Loss:     1.1052 Validation Accuracy: 0.569000
# Epoch 21, CIFAR-10 Batch 5:  Loss:     1.0727 Validation Accuracy: 0.580800
# Epoch 22, CIFAR-10 Batch 1:  Loss:     1.1008 Validation Accuracy: 0.582400
# Epoch 22, CIFAR-10 Batch 2:  Loss:     1.1294 Validation Accuracy: 0.582800
# Epoch 22, CIFAR-10 Batch 3:  Loss:     1.0845 Validation Accuracy: 0.579400
# Epoch 22, CIFAR-10 Batch 4:  Loss:     1.1050 Validation Accuracy: 0.573000
# Epoch 22, CIFAR-10 Batch 5:  Loss:     1.0768 Validation Accuracy: 0.580200
# Epoch 23, CIFAR-10 Batch 1:  Loss:     1.1165 Validation Accuracy: 0.577400
# Epoch 23, CIFAR-10 Batch 2:  Loss:     1.1262 Validation Accuracy: 0.572800
# Epoch 23, CIFAR-10 Batch 3:  Loss:     1.0614 Validation Accuracy: 0.569400
# Epoch 23, CIFAR-10 Batch 4:  Loss:     1.0884 Validation Accuracy: 0.582200
# Epoch 23, CIFAR-10 Batch 5:  Loss:     1.0408 Validation Accuracy: 0.587200
# Epoch 24, CIFAR-10 Batch 1:  Loss:     1.1374 Validation Accuracy: 0.586800
# Epoch 24, CIFAR-10 Batch 2:  Loss:     1.0919 Validation Accuracy: 0.590200
# Epoch 24, CIFAR-10 Batch 3:  Loss:     1.0721 Validation Accuracy: 0.583000
# Epoch 24, CIFAR-10 Batch 4:  Loss:     1.0865 Validation Accuracy: 0.589000
# Epoch 24, CIFAR-10 Batch 5:  Loss:     1.0654 Validation Accuracy: 0.585800
# Epoch 25, CIFAR-10 Batch 1:  Loss:     1.1073 Validation Accuracy: 0.580000
# Epoch 25, CIFAR-10 Batch 2:  Loss:     1.1171 Validation Accuracy: 0.585000
# Epoch 25, CIFAR-10 Batch 3:  Loss:     1.0475 Validation Accuracy: 0.578600
# Epoch 25, CIFAR-10 Batch 4:  Loss:     1.0874 Validation Accuracy: 0.586000
# Epoch 25, CIFAR-10 Batch 5:  Loss:     1.0730 Validation Accuracy: 0.580600
# Epoch 26, CIFAR-10 Batch 1:  Loss:     1.1060 Validation Accuracy: 0.586200
# Epoch 26, CIFAR-10 Batch 2:  Loss:     1.0770 Validation Accuracy: 0.587200
# Epoch 26, CIFAR-10 Batch 3:  Loss:     1.0440 Validation Accuracy: 0.588800
# Epoch 26, CIFAR-10 Batch 4:  Loss:     1.0299 Validation Accuracy: 0.595400
# Epoch 26, CIFAR-10 Batch 5:  Loss:     1.0334 Validation Accuracy: 0.587800
# Epoch 27, CIFAR-10 Batch 1:  Loss:     1.0821 Validation Accuracy: 0.586200
# Epoch 27, CIFAR-10 Batch 2:  Loss:     1.0507 Validation Accuracy: 0.595800
# Epoch 27, CIFAR-10 Batch 3:  Loss:     1.0462 Validation Accuracy: 0.593400
# Epoch 27, CIFAR-10 Batch 4:  Loss:     1.0470 Validation Accuracy: 0.600800
# Epoch 27, CIFAR-10 Batch 5:  Loss:     1.0262 Validation Accuracy: 0.585800
# Epoch 28, CIFAR-10 Batch 1:  Loss:     1.0785 Validation Accuracy: 0.600200
# Epoch 28, CIFAR-10 Batch 2:  Loss:     1.0671 Validation Accuracy: 0.598200
# Epoch 28, CIFAR-10 Batch 3:  Loss:     1.0161 Validation Accuracy: 0.583600
# Epoch 28, CIFAR-10 Batch 4:  Loss:     1.0607 Validation Accuracy: 0.590400
# Epoch 28, CIFAR-10 Batch 5:  Loss:     1.0248 Validation Accuracy: 0.600400
# Epoch 29, CIFAR-10 Batch 1:  Loss:     1.0599 Validation Accuracy: 0.597000
# Epoch 29, CIFAR-10 Batch 2:  Loss:     1.0827 Validation Accuracy: 0.597000
# Epoch 29, CIFAR-10 Batch 3:  Loss:     0.9913 Validation Accuracy: 0.594000
# Epoch 29, CIFAR-10 Batch 4:  Loss:     1.0204 Validation Accuracy: 0.592400
# Epoch 29, CIFAR-10 Batch 5:  Loss:     1.0362 Validation Accuracy: 0.587600
# Epoch 30, CIFAR-10 Batch 1:  Loss:     1.0751 Validation Accuracy: 0.604400
# Epoch 30, CIFAR-10 Batch 2:  Loss:     1.0686 Validation Accuracy: 0.594000
# Epoch 30, CIFAR-10 Batch 3:  Loss:     1.0463 Validation Accuracy: 0.590200
# Epoch 30, CIFAR-10 Batch 4:  Loss:     1.0552 Validation Accuracy: 0.591600
# Epoch 30, CIFAR-10 Batch 5:  Loss:     0.9786 Validation Accuracy: 0.598200
# Epoch 31, CIFAR-10 Batch 1:  Loss:     1.0680 Validation Accuracy: 0.590200
# Epoch 31, CIFAR-10 Batch 2:  Loss:     1.0531 Validation Accuracy: 0.592200
# Epoch 31, CIFAR-10 Batch 3:  Loss:     1.0086 Validation Accuracy: 0.594600
# Epoch 31, CIFAR-10 Batch 4:  Loss:     1.0351 Validation Accuracy: 0.586400
# Epoch 31, CIFAR-10 Batch 5:  Loss:     1.0413 Validation Accuracy: 0.591400
# Epoch 32, CIFAR-10 Batch 1:  Loss:     1.0500 Validation Accuracy: 0.603000
# Epoch 32, CIFAR-10 Batch 2:  Loss:     1.0294 Validation Accuracy: 0.601600
# Epoch 32, CIFAR-10 Batch 3:  Loss:     0.9890 Validation Accuracy: 0.599600
# Epoch 32, CIFAR-10 Batch 4:  Loss:     1.0219 Validation Accuracy: 0.592400
# Epoch 32, CIFAR-10 Batch 5:  Loss:     0.9955 Validation Accuracy: 0.603000
# Epoch 33, CIFAR-10 Batch 1:  Loss:     1.0061 Validation Accuracy: 0.608800
# Epoch 33, CIFAR-10 Batch 2:  Loss:     1.0172 Validation Accuracy: 0.610800
# Epoch 33, CIFAR-10 Batch 3:  Loss:     0.9950 Validation Accuracy: 0.609200
# Epoch 33, CIFAR-10 Batch 4:  Loss:     1.0372 Validation Accuracy: 0.593200
# Epoch 33, CIFAR-10 Batch 5:  Loss:     1.0054 Validation Accuracy: 0.598200
# Epoch 34, CIFAR-10 Batch 1:  Loss:     1.0127 Validation Accuracy: 0.609200
# Epoch 34, CIFAR-10 Batch 2:  Loss:     1.0283 Validation Accuracy: 0.600000
# Epoch 34, CIFAR-10 Batch 3:  Loss:     1.0150 Validation Accuracy: 0.601200
# Epoch 34, CIFAR-10 Batch 4:  Loss:     1.0155 Validation Accuracy: 0.598600
# Epoch 34, CIFAR-10 Batch 5:  Loss:     1.0038 Validation Accuracy: 0.602200
# Epoch 35, CIFAR-10 Batch 1:  Loss:     1.0333 Validation Accuracy: 0.605200
# Epoch 35, CIFAR-10 Batch 2:  Loss:     1.0361 Validation Accuracy: 0.599800
# Epoch 35, CIFAR-10 Batch 3:  Loss:     0.9775 Validation Accuracy: 0.603600
# Epoch 35, CIFAR-10 Batch 4:  Loss:     0.9688 Validation Accuracy: 0.602600
# Epoch 35, CIFAR-10 Batch 5:  Loss:     0.9447 Validation Accuracy: 0.610000
# Epoch 36, CIFAR-10 Batch 1:  Loss:     1.0738 Validation Accuracy: 0.604000
# Epoch 36, CIFAR-10 Batch 2:  Loss:     1.0254 Validation Accuracy: 0.603800
# Epoch 36, CIFAR-10 Batch 3:  Loss:     0.9754 Validation Accuracy: 0.604000
# Epoch 36, CIFAR-10 Batch 4:  Loss:     0.9837 Validation Accuracy: 0.605400
# Epoch 36, CIFAR-10 Batch 5:  Loss:     0.9904 Validation Accuracy: 0.596200
# Epoch 37, CIFAR-10 Batch 1:  Loss:     1.0401 Validation Accuracy: 0.598600
# Epoch 37, CIFAR-10 Batch 2:  Loss:     1.0123 Validation Accuracy: 0.605200
# Epoch 37, CIFAR-10 Batch 3:  Loss:     0.9890 Validation Accuracy: 0.605400
# Epoch 37, CIFAR-10 Batch 4:  Loss:     1.0037 Validation Accuracy: 0.609800
# Epoch 37, CIFAR-10 Batch 5:  Loss:     0.9733 Validation Accuracy: 0.598600
# Epoch 38, CIFAR-10 Batch 1:  Loss:     1.0302 Validation Accuracy: 0.608400
# Epoch 38, CIFAR-10 Batch 2:  Loss:     1.0049 Validation Accuracy: 0.613600
# Epoch 38, CIFAR-10 Batch 3:  Loss:     0.9589 Validation Accuracy: 0.601000
# Epoch 38, CIFAR-10 Batch 4:  Loss:     0.9691 Validation Accuracy: 0.607000
# Epoch 38, CIFAR-10 Batch 5:  Loss:     0.9300 Validation Accuracy: 0.613000
# Epoch 39, CIFAR-10 Batch 1:  Loss:     0.9966 Validation Accuracy: 0.604400
# Epoch 39, CIFAR-10 Batch 2:  Loss:     1.0136 Validation Accuracy: 0.607600
# Epoch 39, CIFAR-10 Batch 3:  Loss:     0.9389 Validation Accuracy: 0.606400
# Epoch 39, CIFAR-10 Batch 4:  Loss:     0.9670 Validation Accuracy: 0.607800
# Epoch 39, CIFAR-10 Batch 5:  Loss:     0.9540 Validation Accuracy: 0.610600
# Epoch 40, CIFAR-10 Batch 1:  Loss:     0.9944 Validation Accuracy: 0.607600
# Epoch 40, CIFAR-10 Batch 2:  Loss:     1.0130 Validation Accuracy: 0.609400
# Epoch 40, CIFAR-10 Batch 3:  Loss:     0.9691 Validation Accuracy: 0.607000
# Epoch 40, CIFAR-10 Batch 4:  Loss:     0.9781 Validation Accuracy: 0.602000
# Epoch 40, CIFAR-10 Batch 5:  Loss:     0.9312 Validation Accuracy: 0.612000
# Epoch 41, CIFAR-10 Batch 1:  Loss:     1.0143 Validation Accuracy: 0.606200
# Epoch 41, CIFAR-10 Batch 2:  Loss:     0.9739 Validation Accuracy: 0.610200
# Epoch 41, CIFAR-10 Batch 3:  Loss:     0.9330 Validation Accuracy: 0.614000
# Epoch 41, CIFAR-10 Batch 4:  Loss:     0.9573 Validation Accuracy: 0.615200
# Epoch 41, CIFAR-10 Batch 5:  Loss:     0.9344 Validation Accuracy: 0.620200
# Epoch 42, CIFAR-10 Batch 1:  Loss:     0.9947 Validation Accuracy: 0.616800
# Epoch 42, CIFAR-10 Batch 2:  Loss:     0.9642 Validation Accuracy: 0.609400
# Epoch 42, CIFAR-10 Batch 3:  Loss:     0.9958 Validation Accuracy: 0.600400
# Epoch 42, CIFAR-10 Batch 4:  Loss:     0.9735 Validation Accuracy: 0.606800
# Epoch 42, CIFAR-10 Batch 5:  Loss:     0.9356 Validation Accuracy: 0.608200
# Epoch 43, CIFAR-10 Batch 1:  Loss:     1.0248 Validation Accuracy: 0.606000
# Epoch 43, CIFAR-10 Batch 2:  Loss:     0.9857 Validation Accuracy: 0.621200
# Epoch 43, CIFAR-10 Batch 3:  Loss:     0.9264 Validation Accuracy: 0.612800
# Epoch 43, CIFAR-10 Batch 4:  Loss:     0.9667 Validation Accuracy: 0.611800
# Epoch 43, CIFAR-10 Batch 5:  Loss:     0.9549 Validation Accuracy: 0.611800
# Epoch 44, CIFAR-10 Batch 1:  Loss:     0.9729 Validation Accuracy: 0.617000
# Epoch 44, CIFAR-10 Batch 2:  Loss:     0.9790 Validation Accuracy: 0.618000
# Epoch 44, CIFAR-10 Batch 3:  Loss:     0.9531 Validation Accuracy: 0.611400
# Epoch 44, CIFAR-10 Batch 4:  Loss:     0.9795 Validation Accuracy: 0.609600
# Epoch 44, CIFAR-10 Batch 5:  Loss:     0.9184 Validation Accuracy: 0.609800
# Epoch 45, CIFAR-10 Batch 1:  Loss:     0.9647 Validation Accuracy: 0.615800
# Epoch 45, CIFAR-10 Batch 2:  Loss:     0.9636 Validation Accuracy: 0.613000
# Epoch 45, CIFAR-10 Batch 3:  Loss:     0.9256 Validation Accuracy: 0.612200
# Epoch 45, CIFAR-10 Batch 4:  Loss:     0.9586 Validation Accuracy: 0.615000
# Epoch 45, CIFAR-10 Batch 5:  Loss:     0.9077 Validation Accuracy: 0.618600
# Epoch 46, CIFAR-10 Batch 1:  Loss:     1.0044 Validation Accuracy: 0.607200
# Epoch 46, CIFAR-10 Batch 2:  Loss:     0.9510 Validation Accuracy: 0.621600
# Epoch 46, CIFAR-10 Batch 3:  Loss:     0.9810 Validation Accuracy: 0.614000
# Epoch 46, CIFAR-10 Batch 4:  Loss:     0.9480 Validation Accuracy: 0.609200
# Epoch 46, CIFAR-10 Batch 5:  Loss:     0.9436 Validation Accuracy: 0.611200
# Epoch 47, CIFAR-10 Batch 1:  Loss:     0.9964 Validation Accuracy: 0.614800
# Epoch 47, CIFAR-10 Batch 2:  Loss:     0.9712 Validation Accuracy: 0.609800
# Epoch 47, CIFAR-10 Batch 3:  Loss:     0.9246 Validation Accuracy: 0.615200
# Epoch 47, CIFAR-10 Batch 4:  Loss:     0.9249 Validation Accuracy: 0.620400
# Epoch 47, CIFAR-10 Batch 5:  Loss:     0.8752 Validation Accuracy: 0.630800
# Epoch 48, CIFAR-10 Batch 1:  Loss:     0.9715 Validation Accuracy: 0.619600
# Epoch 48, CIFAR-10 Batch 2:  Loss:     0.9433 Validation Accuracy: 0.622800
# Epoch 48, CIFAR-10 Batch 3:  Loss:     0.9163 Validation Accuracy: 0.613400
# Epoch 48, CIFAR-10 Batch 4:  Loss:     0.9370 Validation Accuracy: 0.622800
# Epoch 48, CIFAR-10 Batch 5:  Loss:     0.9081 Validation Accuracy: 0.620800
# Epoch 49, CIFAR-10 Batch 1:  Loss:     0.9656 Validation Accuracy: 0.624200
# Epoch 49, CIFAR-10 Batch 2:  Loss:     0.9430 Validation Accuracy: 0.616000
# Epoch 49, CIFAR-10 Batch 3:  Loss:     0.9062 Validation Accuracy: 0.629800
# Epoch 49, CIFAR-10 Batch 4:  Loss:     0.9295 Validation Accuracy: 0.616600
# Epoch 49, CIFAR-10 Batch 5:  Loss:     0.9036 Validation Accuracy: 0.617200
# Epoch 50, CIFAR-10 Batch 1:  Loss:     0.9317 Validation Accuracy: 0.623000
# Epoch 50, CIFAR-10 Batch 2:  Loss:     0.9297 Validation Accuracy: 0.621200
# Epoch 50, CIFAR-10 Batch 3:  Loss:     0.9159 Validation Accuracy: 0.619000
# Epoch 50, CIFAR-10 Batch 4:  Loss:     0.9239 Validation Accuracy: 0.611200
# Epoch 50, CIFAR-10 Batch 5:  Loss:     0.9034 Validation Accuracy: 0.619600
# Epoch 51, CIFAR-10 Batch 1:  Loss:     0.9579 Validation Accuracy: 0.618000
# Epoch 51, CIFAR-10 Batch 2:  Loss:     0.9167 Validation Accuracy: 0.627600
# Epoch 51, CIFAR-10 Batch 3:  Loss:     0.8831 Validation Accuracy: 0.630000
# Epoch 51, CIFAR-10 Batch 4:  Loss:     0.9319 Validation Accuracy: 0.624400
# Epoch 51, CIFAR-10 Batch 5:  Loss:     0.8771 Validation Accuracy: 0.620400
# Epoch 52, CIFAR-10 Batch 1:  Loss:     0.9178 Validation Accuracy: 0.618400
# Epoch 52, CIFAR-10 Batch 2:  Loss:     0.9357 Validation Accuracy: 0.627400
# Epoch 52, CIFAR-10 Batch 3:  Loss:     0.8750 Validation Accuracy: 0.625000
# Epoch 52, CIFAR-10 Batch 4:  Loss:     0.9600 Validation Accuracy: 0.624200
# Epoch 52, CIFAR-10 Batch 5:  Loss:     0.8860 Validation Accuracy: 0.623200
# Epoch 53, CIFAR-10 Batch 1:  Loss:     0.9398 Validation Accuracy: 0.621000
# Epoch 53, CIFAR-10 Batch 2:  Loss:     0.9664 Validation Accuracy: 0.615200
# Epoch 53, CIFAR-10 Batch 3:  Loss:     0.8813 Validation Accuracy: 0.621000
# Epoch 53, CIFAR-10 Batch 4:  Loss:     0.9280 Validation Accuracy: 0.618600
# Epoch 53, CIFAR-10 Batch 5:  Loss:     0.8411 Validation Accuracy: 0.628400
# Epoch 54, CIFAR-10 Batch 1:  Loss:     0.9221 Validation Accuracy: 0.628600
# Epoch 54, CIFAR-10 Batch 2:  Loss:     0.8929 Validation Accuracy: 0.625200
# Epoch 54, CIFAR-10 Batch 3:  Loss:     0.8928 Validation Accuracy: 0.624000
# Epoch 54, CIFAR-10 Batch 4:  Loss:     0.9041 Validation Accuracy: 0.620600
# Epoch 54, CIFAR-10 Batch 5:  Loss:     0.8953 Validation Accuracy: 0.621200
# Epoch 55, CIFAR-10 Batch 1:  Loss:     0.9385 Validation Accuracy: 0.626400
# Epoch 55, CIFAR-10 Batch 2:  Loss:     0.9149 Validation Accuracy: 0.623400
# Epoch 55, CIFAR-10 Batch 3:  Loss:     0.8970 Validation Accuracy: 0.620600
# Epoch 55, CIFAR-10 Batch 4:  Loss:     0.9422 Validation Accuracy: 0.616000
# Epoch 55, CIFAR-10 Batch 5:  Loss:     0.8633 Validation Accuracy: 0.621800
# Epoch 56, CIFAR-10 Batch 1:  Loss:     0.9024 Validation Accuracy: 0.625200
# Epoch 56, CIFAR-10 Batch 2:  Loss:     0.9016 Validation Accuracy: 0.638600
# Epoch 56, CIFAR-10 Batch 3:  Loss:     0.8818 Validation Accuracy: 0.629600
# Epoch 56, CIFAR-10 Batch 4:  Loss:     0.8764 Validation Accuracy: 0.625600
# Epoch 56, CIFAR-10 Batch 5:  Loss:     0.8591 Validation Accuracy: 0.624400
# Epoch 57, CIFAR-10 Batch 1:  Loss:     0.9347 Validation Accuracy: 0.624600
# Epoch 57, CIFAR-10 Batch 2:  Loss:     0.8981 Validation Accuracy: 0.619600
# Epoch 57, CIFAR-10 Batch 3:  Loss:     0.8928 Validation Accuracy: 0.621400
# Epoch 57, CIFAR-10 Batch 4:  Loss:     0.8855 Validation Accuracy: 0.627200
# Epoch 57, CIFAR-10 Batch 5:  Loss:     0.8292 Validation Accuracy: 0.628200
# Epoch 58, CIFAR-10 Batch 1:  Loss:     0.9264 Validation Accuracy: 0.629400
# Epoch 58, CIFAR-10 Batch 2:  Loss:     0.9025 Validation Accuracy: 0.625200
# Epoch 58, CIFAR-10 Batch 3:  Loss:     0.9065 Validation Accuracy: 0.624400
# Epoch 58, CIFAR-10 Batch 4:  Loss:     0.9184 Validation Accuracy: 0.623800
# Epoch 58, CIFAR-10 Batch 5:  Loss:     0.8703 Validation Accuracy: 0.624600
# Epoch 59, CIFAR-10 Batch 1:  Loss:     0.8847 Validation Accuracy: 0.626600
# Epoch 59, CIFAR-10 Batch 2:  Loss:     0.9141 Validation Accuracy: 0.622400
# Epoch 59, CIFAR-10 Batch 3:  Loss:     0.8824 Validation Accuracy: 0.624400
# Epoch 59, CIFAR-10 Batch 4:  Loss:     0.9114 Validation Accuracy: 0.634800
# Epoch 59, CIFAR-10 Batch 5:  Loss:     0.8245 Validation Accuracy: 0.632000
# Epoch 60, CIFAR-10 Batch 1:  Loss:     0.9220 Validation Accuracy: 0.632000
# Epoch 60, CIFAR-10 Batch 2:  Loss:     0.8841 Validation Accuracy: 0.636800
# Epoch 60, CIFAR-10 Batch 3:  Loss:     0.8870 Validation Accuracy: 0.628200
# Epoch 60, CIFAR-10 Batch 4:  Loss:     0.9165 Validation Accuracy: 0.622400
# Epoch 60, CIFAR-10 Batch 5:  Loss:     0.8820 Validation Accuracy: 0.629400
# Epoch 61, CIFAR-10 Batch 1:  Loss:     0.9094 Validation Accuracy: 0.619800
# Epoch 61, CIFAR-10 Batch 2:  Loss:     0.9148 Validation Accuracy: 0.625800
# Epoch 61, CIFAR-10 Batch 3:  Loss:     0.8758 Validation Accuracy: 0.632200
# Epoch 61, CIFAR-10 Batch 4:  Loss:     0.8904 Validation Accuracy: 0.632000
# Epoch 61, CIFAR-10 Batch 5:  Loss:     0.8184 Validation Accuracy: 0.636200
# Epoch 62, CIFAR-10 Batch 1:  Loss:     0.8852 Validation Accuracy: 0.635800
# Epoch 62, CIFAR-10 Batch 2:  Loss:     0.8832 Validation Accuracy: 0.637200
# Epoch 62, CIFAR-10 Batch 3:  Loss:     0.8581 Validation Accuracy: 0.647200
# Epoch 62, CIFAR-10 Batch 4:  Loss:     0.8802 Validation Accuracy: 0.626800
# Epoch 62, CIFAR-10 Batch 5:  Loss:     0.8410 Validation Accuracy: 0.636000
# Epoch 63, CIFAR-10 Batch 1:  Loss:     0.8658 Validation Accuracy: 0.634400
# Epoch 63, CIFAR-10 Batch 2:  Loss:     0.8908 Validation Accuracy: 0.634400
# Epoch 63, CIFAR-10 Batch 3:  Loss:     0.8517 Validation Accuracy: 0.638400
# Epoch 63, CIFAR-10 Batch 4:  Loss:     0.9052 Validation Accuracy: 0.639200
# Epoch 63, CIFAR-10 Batch 5:  Loss:     0.8554 Validation Accuracy: 0.634200
# Epoch 64, CIFAR-10 Batch 1:  Loss:     0.9074 Validation Accuracy: 0.636600
# Epoch 64, CIFAR-10 Batch 2:  Loss:     0.8866 Validation Accuracy: 0.627600
# Epoch 64, CIFAR-10 Batch 3:  Loss:     0.8508 Validation Accuracy: 0.627800
# Epoch 64, CIFAR-10 Batch 4:  Loss:     0.8824 Validation Accuracy: 0.629400
# Epoch 64, CIFAR-10 Batch 5:  Loss:     0.8646 Validation Accuracy: 0.626600
# Epoch 65, CIFAR-10 Batch 1:  Loss:     0.8558 Validation Accuracy: 0.636400
# Epoch 65, CIFAR-10 Batch 2:  Loss:     0.8724 Validation Accuracy: 0.631600
# Epoch 65, CIFAR-10 Batch 3:  Loss:     0.8518 Validation Accuracy: 0.628600
# Epoch 65, CIFAR-10 Batch 4:  Loss:     0.8804 Validation Accuracy: 0.628600
# Epoch 65, CIFAR-10 Batch 5:  Loss:     0.8250 Validation Accuracy: 0.640600
# Epoch 66, CIFAR-10 Batch 1:  Loss:     0.8709 Validation Accuracy: 0.645200
# Epoch 66, CIFAR-10 Batch 2:  Loss:     0.8581 Validation Accuracy: 0.635200
# Epoch 66, CIFAR-10 Batch 3:  Loss:     0.8494 Validation Accuracy: 0.631400
# Epoch 66, CIFAR-10 Batch 4:  Loss:     0.9033 Validation Accuracy: 0.641200
# Epoch 66, CIFAR-10 Batch 5:  Loss:     0.8450 Validation Accuracy: 0.636000
# Epoch 67, CIFAR-10 Batch 1:  Loss:     0.8937 Validation Accuracy: 0.635400
# Epoch 67, CIFAR-10 Batch 2:  Loss:     0.8546 Validation Accuracy: 0.632800
# Epoch 67, CIFAR-10 Batch 3:  Loss:     0.8248 Validation Accuracy: 0.631600
# Epoch 67, CIFAR-10 Batch 4:  Loss:     0.8706 Validation Accuracy: 0.629000
# Epoch 67, CIFAR-10 Batch 5:  Loss:     0.8694 Validation Accuracy: 0.629800
# Epoch 68, CIFAR-10 Batch 1:  Loss:     0.8600 Validation Accuracy: 0.641000
# Epoch 68, CIFAR-10 Batch 2:  Loss:     0.8803 Validation Accuracy: 0.633200
# Epoch 68, CIFAR-10 Batch 3:  Loss:     0.8253 Validation Accuracy: 0.635800
# Epoch 68, CIFAR-10 Batch 4:  Loss:     0.8551 Validation Accuracy: 0.633400
# Epoch 68, CIFAR-10 Batch 5:  Loss:     0.8480 Validation Accuracy: 0.634000
# Epoch 69, CIFAR-10 Batch 1:  Loss:     0.9076 Validation Accuracy: 0.628200
# Epoch 69, CIFAR-10 Batch 2:  Loss:     0.8983 Validation Accuracy: 0.631200
# Epoch 69, CIFAR-10 Batch 3:  Loss:     0.8360 Validation Accuracy: 0.636400
# Epoch 69, CIFAR-10 Batch 4:  Loss:     0.8369 Validation Accuracy: 0.643400
# Epoch 69, CIFAR-10 Batch 5:  Loss:     0.8368 Validation Accuracy: 0.641600
# Epoch 70, CIFAR-10 Batch 1:  Loss:     0.8728 Validation Accuracy: 0.641800
# Epoch 70, CIFAR-10 Batch 2:  Loss:     0.8611 Validation Accuracy: 0.636400
# Epoch 70, CIFAR-10 Batch 3:  Loss:     0.8435 Validation Accuracy: 0.632000
# Epoch 70, CIFAR-10 Batch 4:  Loss:     0.8762 Validation Accuracy: 0.625400
# Epoch 70, CIFAR-10 Batch 5:  Loss:     0.8431 Validation Accuracy: 0.632000
# Epoch 71, CIFAR-10 Batch 1:  Loss:     0.8635 Validation Accuracy: 0.640400
# Epoch 71, CIFAR-10 Batch 2:  Loss:     0.8768 Validation Accuracy: 0.632800
# Epoch 71, CIFAR-10 Batch 3:  Loss:     0.8106 Validation Accuracy: 0.636800
# Epoch 71, CIFAR-10 Batch 4:  Loss:     0.8737 Validation Accuracy: 0.641000
# Epoch 71, CIFAR-10 Batch 5:  Loss:     0.8296 Validation Accuracy: 0.630000
# Epoch 72, CIFAR-10 Batch 1:  Loss:     0.8708 Validation Accuracy: 0.639000
# Epoch 72, CIFAR-10 Batch 2:  Loss:     0.8593 Validation Accuracy: 0.635800
# Epoch 72, CIFAR-10 Batch 3:  Loss:     0.8189 Validation Accuracy: 0.642200
# Epoch 72, CIFAR-10 Batch 4:  Loss:     0.8462 Validation Accuracy: 0.640800
# Epoch 72, CIFAR-10 Batch 5:  Loss:     0.8150 Validation Accuracy: 0.632800
# Epoch 73, CIFAR-10 Batch 1:  Loss:     0.8313 Validation Accuracy: 0.632200
# Epoch 73, CIFAR-10 Batch 2:  Loss:     0.8480 Validation Accuracy: 0.639800
# Epoch 73, CIFAR-10 Batch 3:  Loss:     0.8462 Validation Accuracy: 0.632400
# Epoch 73, CIFAR-10 Batch 4:  Loss:     0.8350 Validation Accuracy: 0.640400
# Epoch 73, CIFAR-10 Batch 5:  Loss:     0.7861 Validation Accuracy: 0.640800
# Epoch 74, CIFAR-10 Batch 1:  Loss:     0.8501 Validation Accuracy: 0.640200
# Epoch 74, CIFAR-10 Batch 2:  Loss:     0.8469 Validation Accuracy: 0.642600
# Epoch 74, CIFAR-10 Batch 3:  Loss:     0.8227 Validation Accuracy: 0.646200
# Epoch 74, CIFAR-10 Batch 4:  Loss:     0.8615 Validation Accuracy: 0.640200
# Epoch 74, CIFAR-10 Batch 5:  Loss:     0.8203 Validation Accuracy: 0.646200
# Epoch 75, CIFAR-10 Batch 1:  Loss:     0.8609 Validation Accuracy: 0.644800
# Epoch 75, CIFAR-10 Batch 2:  Loss:     0.8769 Validation Accuracy: 0.641200
# Epoch 75, CIFAR-10 Batch 3:  Loss:     0.8249 Validation Accuracy: 0.636600
# Epoch 75, CIFAR-10 Batch 4:  Loss:     0.8161 Validation Accuracy: 0.640400
# Epoch 75, CIFAR-10 Batch 5:  Loss:     0.7818 Validation Accuracy: 0.635600
# Epoch 76, CIFAR-10 Batch 1:  Loss:     0.8523 Validation Accuracy: 0.631800
# Epoch 76, CIFAR-10 Batch 2:  Loss:     0.8550 Validation Accuracy: 0.636000
# Epoch 76, CIFAR-10 Batch 3:  Loss:     0.7946 Validation Accuracy: 0.652800
# Epoch 76, CIFAR-10 Batch 4:  Loss:     0.8548 Validation Accuracy: 0.645800
# Epoch 76, CIFAR-10 Batch 5:  Loss:     0.8244 Validation Accuracy: 0.629800
# Epoch 77, CIFAR-10 Batch 1:  Loss:     0.8623 Validation Accuracy: 0.638600
# Epoch 77, CIFAR-10 Batch 2:  Loss:     0.8399 Validation Accuracy: 0.636800
# Epoch 77, CIFAR-10 Batch 3:  Loss:     0.7938 Validation Accuracy: 0.642600
# Epoch 77, CIFAR-10 Batch 4:  Loss:     0.8235 Validation Accuracy: 0.646400
# Epoch 77, CIFAR-10 Batch 5:  Loss:     0.7884 Validation Accuracy: 0.647600
# Epoch 78, CIFAR-10 Batch 1:  Loss:     0.8133 Validation Accuracy: 0.646800
# Epoch 78, CIFAR-10 Batch 2:  Loss:     0.8215 Validation Accuracy: 0.644200
# Epoch 78, CIFAR-10 Batch 3:  Loss:     0.7766 Validation Accuracy: 0.641800
# Epoch 78, CIFAR-10 Batch 4:  Loss:     0.8178 Validation Accuracy: 0.648200
# Epoch 78, CIFAR-10 Batch 5:  Loss:     0.7645 Validation Accuracy: 0.641800
# Epoch 79, CIFAR-10 Batch 1:  Loss:     0.8295 Validation Accuracy: 0.639400
# Epoch 79, CIFAR-10 Batch 2:  Loss:     0.8188 Validation Accuracy: 0.638400
# Epoch 79, CIFAR-10 Batch 3:  Loss:     0.7953 Validation Accuracy: 0.645600
# Epoch 79, CIFAR-10 Batch 4:  Loss:     0.8248 Validation Accuracy: 0.633600
# Epoch 79, CIFAR-10 Batch 5:  Loss:     0.7830 Validation Accuracy: 0.643800
# Epoch 80, CIFAR-10 Batch 1:  Loss:     0.8584 Validation Accuracy: 0.643200
# Epoch 80, CIFAR-10 Batch 2:  Loss:     0.8380 Validation Accuracy: 0.647600
# Epoch 80, CIFAR-10 Batch 3:  Loss:     0.7989 Validation Accuracy: 0.648800
# Epoch 80, CIFAR-10 Batch 4:  Loss:     0.8241 Validation Accuracy: 0.644000
# Epoch 80, CIFAR-10 Batch 5:  Loss:     0.7648 Validation Accuracy: 0.645800
# Epoch 81, CIFAR-10 Batch 1:  Loss:     0.8457 Validation Accuracy: 0.642200
# Epoch 81, CIFAR-10 Batch 2:  Loss:     0.8190 Validation Accuracy: 0.640400
# Epoch 81, CIFAR-10 Batch 3:  Loss:     0.7609 Validation Accuracy: 0.646400
# Epoch 81, CIFAR-10 Batch 4:  Loss:     0.8031 Validation Accuracy: 0.644600
# Epoch 81, CIFAR-10 Batch 5:  Loss:     0.7924 Validation Accuracy: 0.642400
# Epoch 82, CIFAR-10 Batch 1:  Loss:     0.8214 Validation Accuracy: 0.647200
# Epoch 82, CIFAR-10 Batch 2:  Loss:     0.8386 Validation Accuracy: 0.639800
# Epoch 82, CIFAR-10 Batch 3:  Loss:     0.7752 Validation Accuracy: 0.637400
# Epoch 82, CIFAR-10 Batch 4:  Loss:     0.7876 Validation Accuracy: 0.639200
# Epoch 82, CIFAR-10 Batch 5:  Loss:     0.7619 Validation Accuracy: 0.644000
# Epoch 83, CIFAR-10 Batch 1:  Loss:     0.8037 Validation Accuracy: 0.646800
# Epoch 83, CIFAR-10 Batch 2:  Loss:     0.8208 Validation Accuracy: 0.631200
# Epoch 83, CIFAR-10 Batch 3:  Loss:     0.8080 Validation Accuracy: 0.634000
# Epoch 83, CIFAR-10 Batch 4:  Loss:     0.8273 Validation Accuracy: 0.642600
# Epoch 83, CIFAR-10 Batch 5:  Loss:     0.7714 Validation Accuracy: 0.651200
# Epoch 84, CIFAR-10 Batch 1:  Loss:     0.8320 Validation Accuracy: 0.647000
# Epoch 84, CIFAR-10 Batch 2:  Loss:     0.8170 Validation Accuracy: 0.648400
# Epoch 84, CIFAR-10 Batch 3:  Loss:     0.7743 Validation Accuracy: 0.641200
# Epoch 84, CIFAR-10 Batch 4:  Loss:     0.7895 Validation Accuracy: 0.642800
# Epoch 84, CIFAR-10 Batch 5:  Loss:     0.7548 Validation Accuracy: 0.645600
# Epoch 85, CIFAR-10 Batch 1:  Loss:     0.8016 Validation Accuracy: 0.651000
# Epoch 85, CIFAR-10 Batch 2:  Loss:     0.8204 Validation Accuracy: 0.640800
# Epoch 85, CIFAR-10 Batch 3:  Loss:     0.7526 Validation Accuracy: 0.646200
# Epoch 85, CIFAR-10 Batch 4:  Loss:     0.7893 Validation Accuracy: 0.645400
# Epoch 85, CIFAR-10 Batch 5:  Loss:     0.7547 Validation Accuracy: 0.645600
# Epoch 86, CIFAR-10 Batch 1:  Loss:     0.8134 Validation Accuracy: 0.634800
# Epoch 86, CIFAR-10 Batch 2:  Loss:     0.8154 Validation Accuracy: 0.640400
# Epoch 86, CIFAR-10 Batch 3:  Loss:     0.7928 Validation Accuracy: 0.651600
# Epoch 86, CIFAR-10 Batch 4:  Loss:     0.8201 Validation Accuracy: 0.643400
# Epoch 86, CIFAR-10 Batch 5:  Loss:     0.7476 Validation Accuracy: 0.642600
# Epoch 87, CIFAR-10 Batch 1:  Loss:     0.8370 Validation Accuracy: 0.636600
# Epoch 87, CIFAR-10 Batch 2:  Loss:     0.8015 Validation Accuracy: 0.646400
# Epoch 87, CIFAR-10 Batch 3:  Loss:     0.7567 Validation Accuracy: 0.642600
# Epoch 87, CIFAR-10 Batch 4:  Loss:     0.7799 Validation Accuracy: 0.649200
# Epoch 87, CIFAR-10 Batch 5:  Loss:     0.7315 Validation Accuracy: 0.646600
# Epoch 88, CIFAR-10 Batch 1:  Loss:     0.7795 Validation Accuracy: 0.643000
# Epoch 88, CIFAR-10 Batch 2:  Loss:     0.8123 Validation Accuracy: 0.637800
# Epoch 88, CIFAR-10 Batch 3:  Loss:     0.7437 Validation Accuracy: 0.649800
# Epoch 88, CIFAR-10 Batch 4:  Loss:     0.8135 Validation Accuracy: 0.646200
# Epoch 88, CIFAR-10 Batch 5:  Loss:     0.7481 Validation Accuracy: 0.648200
# Epoch 89, CIFAR-10 Batch 1:  Loss:     0.7956 Validation Accuracy: 0.645000
# Epoch 89, CIFAR-10 Batch 2:  Loss:     0.8027 Validation Accuracy: 0.650400
# Epoch 89, CIFAR-10 Batch 3:  Loss:     0.7849 Validation Accuracy: 0.640000
# Epoch 89, CIFAR-10 Batch 4:  Loss:     0.8098 Validation Accuracy: 0.650600
# Epoch 89, CIFAR-10 Batch 5:  Loss:     0.7662 Validation Accuracy: 0.655600
# Epoch 90, CIFAR-10 Batch 1:  Loss:     0.7952 Validation Accuracy: 0.647200
# Epoch 90, CIFAR-10 Batch 2:  Loss:     0.7908 Validation Accuracy: 0.647600
# Epoch 90, CIFAR-10 Batch 3:  Loss:     0.7633 Validation Accuracy: 0.650600
# Epoch 90, CIFAR-10 Batch 4:  Loss:     0.8041 Validation Accuracy: 0.644800
# Epoch 90, CIFAR-10 Batch 5:  Loss:     0.7492 Validation Accuracy: 0.639800
# Epoch 91, CIFAR-10 Batch 1:  Loss:     0.7801 Validation Accuracy: 0.648000
# Epoch 91, CIFAR-10 Batch 2:  Loss:     0.8078 Validation Accuracy: 0.640800
# Epoch 91, CIFAR-10 Batch 3:  Loss:     0.7711 Validation Accuracy: 0.649400
# Epoch 91, CIFAR-10 Batch 4:  Loss:     0.7881 Validation Accuracy: 0.648800
# Epoch 91, CIFAR-10 Batch 5:  Loss:     0.7427 Validation Accuracy: 0.654400
# Epoch 92, CIFAR-10 Batch 1:  Loss:     0.8025 Validation Accuracy: 0.646600
# Epoch 92, CIFAR-10 Batch 2:  Loss:     0.7738 Validation Accuracy: 0.638800
# Epoch 92, CIFAR-10 Batch 3:  Loss:     0.7804 Validation Accuracy: 0.640000
# Epoch 92, CIFAR-10 Batch 4:  Loss:     0.7570 Validation Accuracy: 0.648000
# Epoch 92, CIFAR-10 Batch 5:  Loss:     0.7323 Validation Accuracy: 0.650200
# Epoch 93, CIFAR-10 Batch 1:  Loss:     0.8172 Validation Accuracy: 0.644000
# Epoch 93, CIFAR-10 Batch 2:  Loss:     0.8104 Validation Accuracy: 0.641000
# Epoch 93, CIFAR-10 Batch 3:  Loss:     0.7807 Validation Accuracy: 0.648200
# Epoch 93, CIFAR-10 Batch 4:  Loss:     0.7877 Validation Accuracy: 0.659800
# Epoch 93, CIFAR-10 Batch 5:  Loss:     0.7652 Validation Accuracy: 0.645000
# Epoch 94, CIFAR-10 Batch 1:  Loss:     0.8277 Validation Accuracy: 0.636000
# Epoch 94, CIFAR-10 Batch 2:  Loss:     0.8092 Validation Accuracy: 0.647600
# Epoch 94, CIFAR-10 Batch 3:  Loss:     0.7650 Validation Accuracy: 0.641600
# Epoch 94, CIFAR-10 Batch 4:  Loss:     0.7890 Validation Accuracy: 0.654800
# Epoch 94, CIFAR-10 Batch 5:  Loss:     0.7136 Validation Accuracy: 0.651800
# Epoch 95, CIFAR-10 Batch 1:  Loss:     0.8342 Validation Accuracy: 0.643800
# Epoch 95, CIFAR-10 Batch 2:  Loss:     0.8441 Validation Accuracy: 0.648200
# Epoch 95, CIFAR-10 Batch 3:  Loss:     0.7348 Validation Accuracy: 0.646000
# Epoch 95, CIFAR-10 Batch 4:  Loss:     0.7893 Validation Accuracy: 0.654600
# Epoch 95, CIFAR-10 Batch 5:  Loss:     0.7298 Validation Accuracy: 0.643600
# Epoch 96, CIFAR-10 Batch 1:  Loss:     0.7894 Validation Accuracy: 0.646000
# Epoch 96, CIFAR-10 Batch 2:  Loss:     0.7601 Validation Accuracy: 0.652000
# Epoch 96, CIFAR-10 Batch 3:  Loss:     0.7626 Validation Accuracy: 0.647400
# Epoch 96, CIFAR-10 Batch 4:  Loss:     0.7599 Validation Accuracy: 0.650800
# Epoch 96, CIFAR-10 Batch 5:  Loss:     0.7305 Validation Accuracy: 0.648800
# Epoch 97, CIFAR-10 Batch 1:  Loss:     0.7700 Validation Accuracy: 0.651200
# Epoch 97, CIFAR-10 Batch 2:  Loss:     0.7977 Validation Accuracy: 0.651600
# Epoch 97, CIFAR-10 Batch 3:  Loss:     0.7523 Validation Accuracy: 0.655600
# Epoch 97, CIFAR-10 Batch 4:  Loss:     0.7755 Validation Accuracy: 0.654800
# Epoch 97, CIFAR-10 Batch 5:  Loss:     0.7285 Validation Accuracy: 0.651000
# Epoch 98, CIFAR-10 Batch 1:  Loss:     0.7455 Validation Accuracy: 0.650400
# Epoch 98, CIFAR-10 Batch 2:  Loss:     0.7336 Validation Accuracy: 0.651600
# Epoch 98, CIFAR-10 Batch 3:  Loss:     0.7331 Validation Accuracy: 0.647200
# Epoch 98, CIFAR-10 Batch 4:  Loss:     0.7535 Validation Accuracy: 0.650600
# Epoch 98, CIFAR-10 Batch 5:  Loss:     0.7187 Validation Accuracy: 0.656200
# Epoch 99, CIFAR-10 Batch 1:  Loss:     0.7596 Validation Accuracy: 0.663000
# Epoch 99, CIFAR-10 Batch 2:  Loss:     0.7339 Validation Accuracy: 0.651000
# Epoch 99, CIFAR-10 Batch 3:  Loss:     0.7312 Validation Accuracy: 0.651400
# Epoch 99, CIFAR-10 Batch 4:  Loss:     0.7634 Validation Accuracy: 0.648800
# Epoch 99, CIFAR-10 Batch 5:  Loss:     0.7098 Validation Accuracy: 0.646400
# Epoch 100, CIFAR-10 Batch 1:  Loss:     0.7823 Validation Accuracy: 0.651000
# Epoch 100, CIFAR-10 Batch 2:  Loss:     0.7478 Validation Accuracy: 0.658000
# Epoch 100, CIFAR-10 Batch 3:  Loss:     0.7777 Validation Accuracy: 0.650600
# Epoch 100, CIFAR-10 Batch 4:  Loss:     0.7721 Validation Accuracy: 0.653400
# Epoch 100, CIFAR-10 Batch 5:  Loss:     0.7430 Validation Accuracy: 0.652800

# %% [markdown]
# # Checkpoint
# The model has been saved to disk.
# ## Test Model
# Test your model against the test dataset.  This will be your final accuracy. You should have an accuracy greater than 50%. If you don't, keep tweaking the model architecture and parameters.

# %%
"""
DON'T MODIFY ANYTHING IN THIS CELL
"""
# %matplotlib inline
# %config InlineBackend.figure_format = 'retina'

import tensorflow as tf
import pickle
import helper
import random

# Set batch size if not already set
try:
    if batch_size:
        pass
except NameError:
    batch_size = 64

save_model_path = './image_classification'
n_samples = 4
top_n_predictions = 3

def test_model():
    """
    Test the saved model against the test dataset
    """

    test_features, test_labels = pickle.load(open('preprocess_test.p', mode='rb'))
    loaded_graph = tf.Graph()

    with tf.Session(graph=loaded_graph) as sess:
        # Load model
        loader = tf.train.import_meta_graph(save_model_path + '.meta')
        loader.restore(sess, save_model_path)

        # Get Tensors from loaded model
        loaded_x = loaded_graph.get_tensor_by_name('x:0')
        loaded_y = loaded_graph.get_tensor_by_name('y:0')
        loaded_keep_prob = loaded_graph.get_tensor_by_name('keep_prob:0')
        loaded_logits = loaded_graph.get_tensor_by_name('logits:0')
        loaded_acc = loaded_graph.get_tensor_by_name('accuracy:0')
        
        # Get accuracy in batches for memory limitations
        test_batch_acc_total = 0
        test_batch_count = 0
        
        for test_feature_batch, test_label_batch in helper.batch_features_labels(test_features, test_labels, batch_size):
            test_batch_acc_total += sess.run(
                loaded_acc,
                feed_dict={loaded_x: test_feature_batch, loaded_y: test_label_batch, loaded_keep_prob: 1.0})
            test_batch_count += 1

        print('Testing Accuracy: {}\n'.format(test_batch_acc_total/test_batch_count))

        # Print Random Samples
        random_test_features, random_test_labels = tuple(zip(*random.sample(list(zip(test_features, test_labels)), n_samples)))
        random_test_predictions = sess.run(
            tf.nn.top_k(tf.nn.softmax(loaded_logits), top_n_predictions),
            feed_dict={loaded_x: random_test_features, loaded_y: random_test_labels, loaded_keep_prob: 1.0})
        helper.display_image_predictions(random_test_features, random_test_labels, random_test_predictions)


test_model()
# Out:
# Testing Accuracy: 0.647466915845871

# %% [markdown]
# ## Why 50-80% Accuracy?
# You might be wondering why you can't get an accuracy any higher. First things first, 50% isn't bad for a simple CNN.  Pure guessing would get you 10% accuracy. However, you might notice people are getting scores [well above 80%](http://rodrigob.github.io/are_we_there_yet/build/classification_datasets_results.html#43494641522d3130).  That's because we haven't taught you all there is to know about neural networks. We still need to cover a few more techniques.
# ## Submitting This Project
# When submitting this project, make sure to run all the cells before saving the notebook.  Save the notebook file as "dlnd_image_classification.ipynb" and save it as a HTML file under "File" -> "Download as".  Include the "helper.py" and "problem_unittests.py" files in your submission.
